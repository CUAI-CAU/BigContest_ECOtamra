# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
#from plotly.offline import init_notebook_mode, iplot
#import plotly.graph_objs as go
import os
import warnings

# %% [markdown]
# # 파일 불러와서 열이름 바꾸기

# %%
##### 파일 불러오기 #####
df = pd.read_csv("C:/Users/user/Desktop/2021 빅콘테스트_데이터분석분야_퓨처스리그_ECO제주\data_processing/2_3_short_term_frgn_3_resident_pop_preprocessing.csv", encoding='cp949')

# 시계열 피처단위로 변경
df['base_date'] = pd.to_datetime(df['base_date'])

# base_date를 index로 설정
df.index = df['base_date']
df.columns = ['base_date', 'emd_cd', 'visit_pop_cnt', 'total_pop']  ##### 각자 데이터에 맞게 열이름 변경하기 #####
df
# Out:
#             base_date    emd_cd  visit_pop_cnt  total_pop
# base_date
# 2018-01-31 2018-01-31  50110250     58090.5960      24419
# 2018-02-28 2018-02-28  50110250     69710.8394      24427
# 2018-03-31 2018-03-31  50110250     98026.6381      24532
# 2018-04-30 2018-04-30  50110250    103289.7891      24606
# 2018-05-31 2018-05-31  50110250    115255.9750      24715
# ...               ...       ...            ...        ...
# 2021-02-28 2021-02-28  50130620       280.6159       4173
# 2021-03-31 2021-03-31  50130620      1475.8404       4178
# 2021-04-30 2021-04-30  50130620      1283.0997       4161
# 2021-05-31 2021-05-31  50130620      1212.2652       4178
# 2021-06-30 2021-06-30  50130620      1194.0627       4152
#
# [1806 rows x 4 columns]

# %%
# 필요 없는 열 제거
data = df.drop(['base_date', 'visit_pop_cnt'], 1)     ##### 각자 필요없는 열 제거 #####
data
# Out:
#               emd_cd  total_pop
# base_date
# 2018-01-31  50110250      24419
# 2018-02-28  50110250      24427
# 2018-03-31  50110250      24532
# 2018-04-30  50110250      24606
# 2018-05-31  50110250      24715
# ...              ...        ...
# 2021-02-28  50130620       4173
# 2021-03-31  50130620       4178
# 2021-04-30  50130620       4161
# 2021-05-31  50130620       4178
# 2021-06-30  50130620       4152
#
# [1806 rows x 2 columns]

# %%
# 한 행정동의 행만 추출
sub_area = data['emd_cd'] == 50130590 ##### 각 행정동코드 입력 #####

# base_date, card_amt 만 갖는 df 생성
sub_df = data[sub_area]
sub_df = sub_df.drop('emd_cd', 1)
sub_df
# Out:
#             total_pop
# base_date
# 2018-01-31      13651
# 2018-02-28      13699
# 2018-03-31      13851
# 2018-04-30      13870
# 2018-05-31      13920
# 2018-06-30      13957
# 2018-07-31      14038
# 2018-08-31      14058
# 2018-09-30      14101
# 2018-10-31      14127
# 2018-11-30      14148
# 2018-12-31      14156
# 2019-01-31      14353
# 2019-02-28      14480
# 2019-03-31      14540
# 2019-04-30      14556
# 2019-05-31      14574
# 2019-06-30      14552
# 2019-07-31      14569
# 2019-08-31      14560
# 2019-09-30      14579
# 2019-10-31      14595
# 2019-11-30      14611
# 2019-12-31      14657
# 2020-01-31      14692
# 2020-02-29      14713
# 2020-03-31      14678
# 2020-04-30      14674
# 2020-05-31      14675
# 2020-06-30      14725
# 2020-07-31      14750
# 2020-08-31      14770
# 2020-09-30      14780
# 2020-10-31      14831
# 2020-11-30      14854
# 2020-12-31      14963
# 2021-01-31      15022
# 2021-02-28      15097
# 2021-03-31      15146
# 2021-04-30      15223
# 2021-05-31      15239
# 2021-06-30      15277

# %%
# series 형으로 변환
sub_df.to_dict('series')
# Out:
# {'total_pop': base_date
#  2018-01-31    13651
#  2018-02-28    13699
#  2018-03-31    13851
#  2018-04-30    13870
#  2018-05-31    13920
#  2018-06-30    13957
#  2018-07-31    14038
#  2018-08-31    14058
#  2018-09-30    14101
#  2018-10-31    14127
#  2018-11-30    14148
#  2018-12-31    14156
#  2019-01-31    14353
#  2019-02-28    14480
#  2019-03-31    14540
#  2019-04-30    14556
#  2019-05-31    14574
#  2019-06-30    14552
#  2019-07-31    14569
#  2019-08-31    14560
#  2019-09-30    14579
#  2019-10-31    14595
#  2019-11-30    14611
#  2019-12-31    14657
#  2020-01-31    14692
#  2020-02-29    14713
#  2020-03-31    14678
#  2020-04-30    14674
#  2020-05-31    14675
#  2020-06-30    14725
#  2020-07-31    14750
#  2020-08-31    14770
#  2020-09-30    14780
#  2020-10-31    14831
#  2020-11-30    14854
#  2020-12-31    14963
#  2021-01-31    15022
#  2021-02-28    15097
#  2021-03-31    15146
#  2021-04-30    15223
#  2021-05-31    15239
#  2021-06-30    15277
#  Name: total_pop, dtype: int64}

# %% [markdown]
# # ARIMA

# %%
# ARIMA에 적합한 float로 바꾸는 과정
sub_df_float = sub_df[:].astype(np.float)
#sub_df_float.tail()

# %%
# ADF 검정 - 정상성 확인하는 검정 (귀무 : 정상성 만족 x, 대립 : 정상성 만족)
from statsmodels.tsa.stattools import adfuller

result = adfuller(sub_df)
print('ADF Statistic : %f' % result[0])
print('p-value : %f' % result[1])
print('Critical Values :')
for key, value in result[4].items():
    print('\t%s: %3f' % (key, value))
    
##### 여기서 p-value 확인 -> 0.05보다 크면 아래로 내려가서 차분하기 / 작으면 차분 생략(아래 셀 생략) #####
# Out:
# ADF Statistic : -1.164220
# p-value : 0.688795
# Critical Values :
# 	1%: -3.605565
# 	5%: -2.937069
# 	10%: -2.606986

# %%
# 차분
diff_1 = sub_df_float.diff(periods=1).iloc[1:]

# ADF 검정 - 정상성 확인하는 검정 (귀무 : 정상성 만족 x, 대립 : 정상성 만족)
result = adfuller(diff_1)
print('ADF Statistic : %f' % result[0])
print('p-value : %f' % result[1])
print('Critical Values :')
for key, value in result[4].items():
    print('\t%s: %3f' % (key, value))
    
##### 여기서 또 p-value 확인 -> 0.05보다 크면 이 파일 안되고 log파일로 넘어가세요 / 작으면 아래로 쭉 진행 #####
# Out:
# ADF Statistic : -4.668104
# p-value : 0.000097
# Critical Values :
# 	1%: -3.605565
# 	5%: -2.937069
# 	10%: -2.606986

# %%
#!pip install pmdarima

# %%
from pmdarima.arima import auto_arima

model_arima= auto_arima(sub_df,trace=True, error_action='ignore',suppress_warnings=True,stepwise=False,seasonal=True)

model_arima.fit(sub_df)

##### 여기서 아래쪽에 'Best model:  ARIMA(0,1,0)(0,0,0)[1] intercept' 이렇게 나오면 (0,1,0) 가져다 쓸거임 #####
##### ARIMA(0,1,0) 여기 숫자 세 개만 잘 보면 됨 !!!! #####
# Out:
#  ARIMA(0,1,0)(0,0,0)[1] intercept   : AIC=430.350, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[1] intercept   : AIC=430.130, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[1] intercept   : AIC=429.406, Time=0.17 sec
#  ARIMA(0,1,3)(0,0,0)[1] intercept   : AIC=430.811, Time=0.11 sec
#  ARIMA(0,1,4)(0,0,0)[1] intercept   : AIC=431.379, Time=0.15 sec
#  ARIMA(0,1,5)(0,0,0)[1] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(1,1,0)(0,0,0)[1] intercept   : AIC=429.247, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[1] intercept   : AIC=430.918, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[1] intercept   : AIC=422.725, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[1] intercept   : AIC=424.420, Time=0.28 sec
#  ARIMA(1,1,4)(0,0,0)[1] intercept   : AIC=425.552, Time=0.35 sec
#  ARIMA(2,1,0)(0,0,0)[1] intercept   : AIC=430.355, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,0)[1] intercept   : AIC=426.481, Time=0.37 sec
#  ARIMA(2,1,2)(0,0,0)[1] intercept   : AIC=424.227, Time=0.39 sec
#  ARIMA(2,1,3)(0,0,0)[1] intercept   : AIC=426.666, Time=0.20 sec
#  ARIMA(3,1,0)(0,0,0)[1] intercept   : AIC=429.790, Time=0.16 sec
#  ARIMA(3,1,1)(0,0,0)[1] intercept   : AIC=426.940, Time=0.26 sec
#  ARIMA(3,1,2)(0,0,0)[1] intercept   : AIC=425.027, Time=0.30 sec
#  ARIMA(4,1,0)(0,0,0)[1] intercept   : AIC=430.634, Time=0.14 sec
#  ARIMA(4,1,1)(0,0,0)[1] intercept   : AIC=428.611, Time=0.26 sec
#  ARIMA(5,1,0)(0,0,0)[1] intercept   : AIC=430.191, Time=0.30 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[1] intercept
# Total fit time: 4.185 seconds
# ARIMA(order=(1, 1, 2), scoring_args={}, seasonal_order=(0, 0, 0, 1),
#       suppress_warnings=True)

# %%
# ARIMA 모델 
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# (AR=2, 차분=1, MA=2) 파라미터로 ARIMA 모델을 학습합니다.
model = ARIMA(sub_df.total_pop.values, order=(2,1,2))     ##### 여기 order=(0,1,0)에 위에서 나온 숫자 넣는거 #####
                                    ##### 그리고 sub_df.card_amt.values에서 가운데 card_amt 각자걸로 바꾸기 #####

#trend : constant를 가지고 있는지, c - constant / nc - no constant
#disp : 수렴 정보를 나타냄
model_fit = model.fit(trend='c', full_output=True, disp=True)
print(model_fit.summary())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                   41
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -212.916
# Method:                       css-mle   S.D. of innovations             42.859
# Date:                Sat, 11 Sep 2021   AIC                            437.833
# Time:                        01:28:57   BIC                            448.114
# Sample:                             1   HQIC                           441.576
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.6868      6.974      5.691      0.000      26.018      53.355
# ar.L1.D.y     -0.3041      0.173     -1.758      0.079      -0.643       0.035
# ar.L2.D.y     -0.9576      0.100     -9.546      0.000      -1.154      -0.761
# ma.L1.D.y      0.3561      0.222      1.605      0.108      -0.079       0.791
# ma.L2.D.y      1.0000      0.853      1.173      0.241      -0.671       2.671
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.1588           -1.0095j            1.0219           -0.2748
# AR.2           -0.1588           +1.0095j            1.0219            0.2748
# MA.1           -0.1781           -0.9840j            1.0000           -0.2785
# MA.2           -0.1781           +0.9840j            1.0000            0.2785
# -----------------------------------------------------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %% [markdown]
# # 예측하기

# %%
# 2단위 이후의 예측결과
fore = model_fit.forecast(steps=2)
print(fore)

##### 맨 앞에 나온 'array([10681271.81014634, 10741037.02029268])' 이게 차례대로 7, 8월 예측값임 #####
##### 7월 : 10681271.81014634, 8월 : 10741037.02029268 #####
##### 이 값 가져다 엑셀파일에 입력하기 #####
# Out:
# (array([15320.70992897, 15360.78864422]), array([42.85862581, 62.20903189]), array([[15236.70856595, 15404.71129199],
#        [15238.86118219, 15482.71610624]]))
