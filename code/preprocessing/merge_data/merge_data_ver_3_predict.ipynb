# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_excel("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\arima_korean.xlsx")
data2 = pd.read_excel("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\arima_short_term_frgn, resident_2.xlsx")
data3 = pd.read_excel("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\arima_card_amt_card_cnt.xlsx")
data4 = pd.read_excel("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\arima_waste_cnt.xlsx")
data5 = pd.read_csv("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\house_7,8_preprocessing.csv")
data6 = pd.read_csv("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\distancing_7,8_preprocessing.csv")

# %%
data5['base_date'] = pd.to_datetime(data5['base_date'], format="%Y-%m-%d")
data6['base_date'] = pd.to_datetime(data6['base_date'], format="%Y-%m-%d")

# %%
data_merge = pd.merge(data1, data2, on=['base_date', 'emd_cd'])
data_merge = pd.merge(data_merge, data3, on=['base_date', 'emd_cd'])
data_merge = pd.merge(data_merge, data4, on=['base_date', 'emd_cd'])
data_merge = pd.merge(data_merge, data5, on=['base_date', 'emd_cd'])
data_merge = pd.merge(data_merge, data6, on=['base_date', 'emd_cd'])
data_merge
# Out:
#     base_date    emd_cd        korean  long_term_frgn  short_term_frgn  \
# 0  2021-07-31  50110250  8.684900e+06   469672.434947       387.934302
# 1  2021-08-31  50110250  8.084718e+06   487440.026239         0.000000
# 2  2021-07-31  50110253  1.840661e+07   767679.832251     24078.524659
# 3  2021-08-31  50110253  1.724375e+07   738378.189646     20402.217817
# 4  2021-07-31  50110256  7.144597e+06   171265.969852       564.443777
# ..        ...       ...           ...             ...              ...
# 81 2021-08-31  50130600  4.387631e+06   107985.071393         0.000000
# 82 2021-07-31  50130610  4.226366e+06   211468.254785      3231.755998
# 83 2021-08-31  50130610  4.080363e+06   227339.915343      2503.870872
# 84 2021-07-31  50130620  5.586203e+06   144703.303893         0.000000
# 85 2021-08-31  50130620  5.573783e+06   144105.245217         0.000000
#
#         resident      card_amt    card_cnt     waste_cnt  detached   apt  \
# ...

# %%
data = pd.read_csv("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\ver_3_merge_data.csv")
data
# Out:
#        base_date    emd_cd        korean  long_term_frgn  short_term_frgn  \
# 0     2019-11-30  50110250  7.321788e+06     469689.3527      129161.4006
# 1     2019-12-31  50110250  6.915173e+06     482920.2385      122124.6609
# 2     2020-01-31  50110250  7.476137e+06     587299.9640      112758.3034
# 3     2020-02-29  50110250  5.561978e+06     559439.3959       60252.7989
# 4     2020-03-31  50110250  6.094369e+06     714445.0812       29661.4429
# ...          ...       ...           ...             ...              ...
# 1629  2021-02-28  50130620  4.321265e+06     109325.4866         280.6159
# 1630  2021-03-31  50130620  4.744309e+06     118258.8891        1475.8404
# 1631  2021-04-30  50130620  5.236706e+06     129227.7480        1283.0997
# 1632  2021-05-31  50130620  5.805413e+06     144213.2650        1212.2652
# 1633  2021-06-30  50130620  5.705196e+06     146956.6848        1194.0627
#
#       resident    card_cnt     card_amt  waste_cnt  detached    apt   town  \
# ...

# %%
result = data.append(data_merge)
result
# Out:
#               base_date    emd_cd        korean  long_term_frgn  \
# 0            2019-11-30  50110250  7.321788e+06   469689.352700
# 1            2019-12-31  50110250  6.915173e+06   482920.238500
# 2            2020-01-31  50110250  7.476137e+06   587299.964000
# 3            2020-02-29  50110250  5.561978e+06   559439.395900
# 4            2020-03-31  50110250  6.094369e+06   714445.081200
# ..                  ...       ...           ...             ...
# 81  2021-08-31 00:00:00  50130600  4.387631e+06   107985.071393
# 82  2021-07-31 00:00:00  50130610  4.226366e+06   211468.254785
# 83  2021-08-31 00:00:00  50130610  4.080363e+06   227339.915343
# 84  2021-07-31 00:00:00  50130620  5.586203e+06   144703.303893
# 85  2021-08-31 00:00:00  50130620  5.573783e+06   144105.245217
#
#     short_term_frgn      resident    card_cnt      card_amt     waste_cnt  \
# 0     129161.400600  25149.000000  267.380645  9.586590e+06    620.000000
# ...

# %%
result.to_csv("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\ver_3_merge_data_predict.csv", index_label=False)

# %%
pd.read_csv("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\ver_3_merge_data_predict.csv")
# Out:
#               base_date    emd_cd        korean  long_term_frgn  \
# 0            2019-11-30  50110250  7.321788e+06   469689.352700
# 1            2019-12-31  50110250  6.915173e+06   482920.238500
# 2            2020-01-31  50110250  7.476137e+06   587299.964000
# 3            2020-02-29  50110250  5.561978e+06   559439.395900
# 4            2020-03-31  50110250  6.094369e+06   714445.081200
# ..                  ...       ...           ...             ...
# 81  2021-08-31 00:00:00  50130600  4.387631e+06   107985.071393
# 82  2021-07-31 00:00:00  50130610  4.226366e+06   211468.254785
# 83  2021-08-31 00:00:00  50130610  4.080363e+06   227339.915343
# 84  2021-07-31 00:00:00  50130620  5.586203e+06   144703.303893
# 85  2021-08-31 00:00:00  50130620  5.573783e+06   144105.245217
#
#     short_term_frgn      resident    card_cnt      card_amt     waste_cnt  \
# 0     129161.400600  25149.000000  267.380645  9.586590e+06    620.000000
# ...
