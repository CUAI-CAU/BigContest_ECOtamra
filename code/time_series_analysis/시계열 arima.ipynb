# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# a = pd.Series.from_csv("C:/Users/user/Desktop/2021 빅콘테스트_데이터분석분야_퓨처스리그_ECO제주_데이터_210811_update/데이터 전처리/ver_1_merge_data.csv", header=0, parse_dates=True, encoding='cp949')
# a

# %%
df = pd.read_csv("C:\\Users\\asus\\BigContest\\files\\data_preprocessing\\ver_1_merge_data.csv", encoding='cp949')
df
# Out:
#        base_date    emd_cd        korean  long_term_frgn  short_term_frgn  \
# 0     2019-11-30  50110250  7.321788e+06     469689.3527      129161.4006
# 1     2019-12-31  50110250  6.915173e+06     482920.2385      122124.6609
# 2     2020-01-31  50110250  7.476137e+06     587299.9640      112758.3034
# 3     2020-02-29  50110250  5.561978e+06     559439.3959       60252.7989
# 4     2020-03-31  50110250  6.094369e+06     714445.0812       29661.4429
# ...          ...       ...           ...             ...              ...
# 1629  2021-02-28  50130620  4.321265e+06     109325.4866         280.6159
# 1630  2021-03-31  50130620  4.744309e+06     118258.8891        1475.8404
# 1631  2021-04-30  50130620  5.236706e+06     129227.7480        1283.0997
# 1632  2021-05-31  50130620  5.805413e+06     144213.2650        1212.2652
# 1633  2021-06-30  50130620  5.705196e+06     146956.6848        1194.0627
#
#       resident    card_cnt     card_amt  waste_cnt  waste_amt
# ...

# %%
# 필요 없는 행 제거
data = df.drop(['long_term_frgn', 'short_term_frgn', 'resident', 'card_cnt', 'card_amt', 'waste_cnt', 'waste_amt'], 1)
data
# Out:
#        base_date    emd_cd        korean
# 0     2019-11-30  50110250  7.321788e+06
# 1     2019-12-31  50110250  6.915173e+06
# 2     2020-01-31  50110250  7.476137e+06
# 3     2020-02-29  50110250  5.561978e+06
# 4     2020-03-31  50110250  6.094369e+06
# ...          ...       ...           ...
# 1629  2021-02-28  50130620  4.321265e+06
# 1630  2021-03-31  50130620  4.744309e+06
# 1631  2021-04-30  50130620  5.236706e+06
# 1632  2021-05-31  50130620  5.805413e+06
# 1633  2021-06-30  50130620  5.705196e+06
#
# [1634 rows x 3 columns]

# %%
# 시계열 피처단위로 변경
df['base_date'] = pd.to_datetime(df['base_date'])

# base_date를 index로 설정
df.index = df['base_date']
df
# Out:
#             base_date    emd_cd        korean  long_term_frgn  \
# base_date
# 2019-11-30 2019-11-30  50110250  7.321788e+06     469689.3527
# 2019-12-31 2019-12-31  50110250  6.915173e+06     482920.2385
# 2020-01-31 2020-01-31  50110250  7.476137e+06     587299.9640
# 2020-02-29 2020-02-29  50110250  5.561978e+06     559439.3959
# 2020-03-31 2020-03-31  50110250  6.094369e+06     714445.0812
# ...               ...       ...           ...             ...
# 2021-02-28 2021-02-28  50130620  4.321265e+06     109325.4866
# 2021-03-31 2021-03-31  50130620  4.744309e+06     118258.8891
# 2021-04-30 2021-04-30  50130620  5.236706e+06     129227.7480
# 2021-05-31 2021-05-31  50130620  5.805413e+06     144213.2650
# 2021-06-30 2021-06-30  50130620  5.705196e+06     146956.6848
#
#             short_term_frgn  resident    card_cnt     card_amt  waste_cnt  \
# base_date
# 2019-11-30      129161.4006     25149  267.380645  9586590.265        620
# ...

# %%
# 한 행정동의 행만 추출
sub_area = data['emd_cd'] == 50110250

# base_date, korean 만 갖는 df 생성
sub_df = data[sub_area]
sub_df = sub_df.drop('emd_cd', 1)
sub_df
# Out:
#      base_date        korean
# 0   2019-11-30  7.321788e+06
# 1   2019-12-31  6.915173e+06
# 2   2020-01-31  7.476137e+06
# 3   2020-02-29  5.561978e+06
# 4   2020-03-31  6.094369e+06
# 5   2020-04-30  5.684751e+06
# 6   2020-05-31  6.776586e+06
# 7   2020-06-30  7.621125e+06
# 8   2020-07-31  8.100981e+06
# 9   2020-08-31  9.569720e+06
# 10  2020-09-30  7.014126e+06
# 11  2020-10-31  8.147031e+06
# 12  2020-11-30  7.993247e+06
# 13  2020-12-31  6.533004e+06
# 14  2021-01-31  6.195203e+06
# 15  2021-02-28  6.646771e+06
# 16  2021-03-31  7.840074e+06
# 17  2021-04-30  8.781502e+06
# 18  2021-05-31  9.036917e+06
# 19  2021-06-30  9.251269e+06

# %%
from matplotlib import pyplot as plt

# 전체 그래프 확인
plt.figure(figsize=(22,8))
plt.plot(sub_df.base_date, sub_df.korean)
plt.xlabel("date")
plt.ylabel("korean")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#from plotly.offline import init_notebook_mode, iplot
#import plotly.graph_objs as go
import os
import warnings

# %%
# 시계열 분해
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(sub_df['korean'], model='additive', freq=3) #분기별 데이터 4, 월별 데이터는 24, 맞춰가기

fig = plt.figure()
fig = result.plot()
fig.set_size_inches(20,10)
# Out:
# <ipython-input-9-ad39d997b667>:3: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   result = seasonal_decompose(sub_df['korean'], model='additive', freq=3) #분기별 데이터 4, 월별 데이터는 24, 맞춰가기

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# ARIMA에 적합한 float로 바꾸는 과정
sub_df_float = sub_df[:].astype(np.float)
#sub_df_float.tail()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3084aaa91521> in <module>
#       1 # ARIMA에 적합한 float로 바꾸는 과정
# ----> 2 sub_df_float = sub_df[:].astype(np.float)
#       3 #sub_df_float.tail()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
# ...

# %%
# 정상성 평가 - acf, pacf 그래프

plot_acf(sub_df)
plot_pacf(sub_df)
plt.figure(figsize=(20,4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-efc52f362779> in <module>
#       1 # 정상성 평가 - acf, pacf 그래프
#       2
# ----> 3 plot_acf(sub_df)
#       4 plot_pacf(sub_df)
#       5 plt.figure(figsize=(20,4))
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, adjusted, fft, missing, title, zero, vlines_kwargs, **kwargs)
#     175     confint = None
#     176     # acf has different return type based on alpha
# --> 177     acf_x = acf(
#     178         x,
#     179         nlags=nlags,
#
# ...

# %%
#  ACF 그래프 - 천천히 감소할 시 정상성 만족 x
import statsmodels.api as sm

fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sub_df, lags=20, ax=ax1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-419d13f41829> in <module>
#       4 fig = plt.figure(figsize=(20,8))
#       5 ax1 = fig.add_subplot(211)
# ----> 6 fig = sm.graphics.tsa.plot_acf(sub_df, lags=20, ax=ax1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, adjusted, fft, missing, title, zero, vlines_kwargs, **kwargs)
#     175     confint = None
#     176     # acf has different return type based on alpha
# --> 177     acf_x = acf(
#     178         x,
#     179         nlags=nlags,
#
# ...

# %%
# ADF 검정 - 정상성 확인하는 검정 (귀무 : 정상성 만족 x, 대립 : 정상성 만족)

from statsmodels.tsa.stattools import adfuller
result = adfuller(sub_df)
print('ADF Statistic : %f' % result[0])
print('p-value : %f' % result[1])
print('Critical Values :')
for key, value in result[4].items():
    print('\t%s: %3f' % (key, value))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-81546a9888bb> in <module>
#       2
#       3 from statsmodels.tsa.stattools import adfuller
# ----> 4 result = adfuller(sub_df)
#       5 print('ADF Statistic : %f' % result[0])
#       6 print('p-value : %f' % result[1])
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     247     See example notebook
#     248     """
# --> 249     x = array_like(x, "x")
#     250     maxlag = int_like(maxlag, "maxlag", optional=True)
#     251     regression = string_like(
#
# ~\anaconda3\lib\site-packages\statsmodels\tools\validation\validation.py in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#     133     if optional and obj is None:
#     134         return None
# ...

# %%
# 차분 - 최대 2회
diff_1 = sub_df_float.diff(periods=1).iloc[1:]
diff_1.plot()
plot_acf(diff_1)
plot_pacf(diff_1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-322e8426e4e0> in <module>
#       1 # 차분 - 최대 2회
# ----> 2 diff_1 = sub_df_float.diff(periods=1).iloc[1:]
#       3 diff_1.plot()
#       4 plot_acf(diff_1)
#       5 plot_pacf(diff_1)
#
# NameError: name 'sub_df_float' is not defined

# %%
# ARIMA 적용
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults

model = ARIMA(sub_df, order=(1,1,0))
model_fit = model.fit(trend='c', full_output=True, disp=1) # trend='c' or trend='nc'(상수 포함 제한)
print(model_fit.summary()
# Out:
#   File "<ipython-input-17-620961905c4c>", line 7
#     print(model_fit.summary()
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
# ARIMA 예측모델 plot 확인
model_fit.plot_predict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2885a977c74e> in <module>
#       1 # ARIMA 예측모델 plot 확인
# ----> 2 model_fit.plot_predict()
#
# NameError: name 'model_fit' is not defined

# %%
# 1단위 이후의 예측결과
fore = model_fit.forecast(steps=1)
print(fore)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-feb0120b961a> in <module>
#       1 # 1단위 이후의 예측결과
# ----> 2 fore = model_fit.forecast(steps=1)
#       3 print(fore)
#
# NameError: name 'model_fit' is not defined

# %%
# 2단위 이후의 예측결과
fore = model_fit.forecast(steps=1)
print(fore)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f416670551a6> in <module>
#       1 # 2단위 이후의 예측결과
# ----> 2 fore = model_fit.forecast(steps=1)
#       3 print(fore)
#
# NameError: name 'model_fit' is not defined

# %%
from pmdarima.arima import auto_arima

model_arima= auto_arima(train,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,suppress_warnings=True,stepwise=False,seasonal=False)

model_arima.fit(train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-a4b8e0d88388> in <module>
# ----> 1 from pmdarima.arima import auto_arima
#       2
#       3 model_arima= auto_arima(train,trace=True, error_action='ignore', start_p=1,start_q=1,max_p=3,max_q=3,suppress_warnings=True,stepwise=False,seasonal=False)
#       4
#       5 model_arima.fit(train)
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
# ARIMA 모델 

from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# (AR=2, 차분=1, MA=2) 파라미터로 ARIMA 모델을 학습합니다.
model = ARIMA(df.korean.values, order=(2,1,2))

#trend : constant를 가지고 있는지, c - constant / nc - no constant
#disp : 수렴 정보를 나타냄
model_fit = model.fit(trend='c', full_output=True, disp=True)
print(model_fit.summary())
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#                              ARIMA Model Results
# ...

# %%
# ARIMA 모델 학습에 의한 예측결과
forecast_data = model_fit.forecast(steps=5) # 학습 데이터셋으로부터 5일 뒤를 예측합니다.

# 테스트 데이터셋을 불러옵니다.
test_file_path = '../data/market-price-test.csv'
bitcoin_test_df = pd.read_csv(test_file_path, names=['ds', 'y'])

pred_y = forecast_data[0].tolist() # 마지막 5일의 예측 데이터입니다. (2018-08-27 ~ 2018-08-31)
test_y = bitcoin_test_df.y.values # 실제 5일 가격 데이터입니다. (2018-08-27 ~ 2018-08-31)
pred_y_lower = [] # 마지막 5일의 예측 데이터의 최소값입니다.
pred_y_upper = [] # 마지막 5일의 예측 데이터의 최대값입니다.
for lower_upper in forecast_data[2]:
    lower = lower_upper[0]
    upper = lower_upper[1]
    pred_y_lower.append(lower)
    pred_y_upper.append(upper)
    
plt.plot(pred_y, color="gold") # 모델이 예상한 가격 그래프입니다.
plt.plot(pred_y_lower, color="red") # 모델이 예상한 최소가격 그래프입니다.
plt.plot(pred_y_upper, color="blue") # 모델이 예상한 최대가격 그래프입니다.
plt.plot(test_y, color="green") # 실제 가격 그래프입니다.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-64025e464127> in <module>
#       4 # 테스트 데이터셋을 불러옵니다.
#       5 test_file_path = '../data/market-price-test.csv'
# ----> 6 bitcoin_test_df = pd.read_csv(test_file_path, names=['ds', 'y'])
#       7
#       8 pred_y = forecast_data[0].tolist() # 마지막 5일의 예측 데이터입니다. (2018-08-27 ~ 2018-08-31)
#
# ...
