dtype: float64}

# %% [markdown]
# # ARIMA

# %%
# ARIMA에 적합한 log로 바꾸는 과정
sub_df_log = np.log1p(sub_df[:])
#sub_df_float.tail()

# %%
# ADF 검정 - 정상성 확인하는 검정 (귀무 : 정상성 만족 x, 대립 : 정상성 만족)
from statsmodels.tsa.stattools import adfuller

result = adfuller(sub_df_log)
print('ADF Statistic : %f' % result[0])
print('p-value : %f' % result[1])
print('Critical Values :')
for key, value in result[4].items():
    print('\t%s: %3f' % (key, value))
    
##### 여기서 p-value 확인 -> 0.05보다 크면 아래로 내려가서 차분하기 / 작으면 차분 생략(아래 셀 생략) #####
# Out:
# ADF Statistic : -0.595296
# p-value : 0.872041
# Critical Values :
# 	1%: -3.605565
# 	5%: -2.937069
# 	10%: -2.606986

# %%
# 차분
diff_1 = sub_df_log.diff(periods=1).iloc[1:]

# ADF 검정 - 정상성 확인하는 검정 (귀무 : 정상성 만족 x, 대립 : 정상성 만족)
result = adfuller(diff_1)
print('ADF Statistic : %f' % result[0])
print('p-value : %f' % result[1])
print('Critical Values :')
for key, value in result[4].items():
    print('\t%s: %3f' % (key, value))
    
##### 여기서 또 p-value 확인 -> 0.05보다 크면 얼른 단톡에 보고하기 / 작으면 아래로 쭉 진행 #####
# Out:
# ADF Statistic : -4.872386
# p-value : 0.000039
# Critical Values :
# 	1%: -3.605565
# 	5%: -2.937069
# 	10%: -2.606986

# %%
#!pip install pmdarima

# %%
from pmdarima.arima import auto_arima

model_arima= auto_arima(sub_df_log,trace=True, error_action='ignore',suppress_warnings=True,stepwise=False,seasonal=True)

model_arima.fit(sub_df_log)

##### 여기서 아래쪽에 'Best model:  ARIMA(1,1,1)(0,0,0)[1] intercept' 이렇게 나오면 (1,1,1) 가져다 쓸거임 #####
##### ARIMA(1,1,1) 여기 숫자 세 개만 잘 보면 됨 !!!! #####
# Out:
#  ARIMA(0,1,0)(0,0,0)[1] intercept   : AIC=72.626, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[1] intercept   : AIC=72.181, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[1] intercept   : AIC=74.082, Time=0.22 sec
#  ARIMA(0,1,3)(0,0,0)[1] intercept   : AIC=75.746, Time=0.12 sec
#  ARIMA(0,1,4)(0,0,0)[1] intercept   : AIC=77.689, Time=0.19 sec
#  ARIMA(0,1,5)(0,0,0)[1] intercept   : AIC=78.990, Time=0.38 sec
#  ARIMA(1,1,0)(0,0,0)[1] intercept   : AIC=72.431, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[1] intercept   : AIC=74.003, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[1] intercept   : AIC=75.988, Time=0.18 sec
#  ARIMA(1,1,3)(0,0,0)[1] intercept   : AIC=77.728, Time=0.18 sec
#  ARIMA(1,1,4)(0,0,0)[1] intercept   : AIC=inf, Time=1.01 sec
#  ARIMA(2,1,0)(0,0,0)[1] intercept   : AIC=74.320, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,0)[1] intercept   : AIC=75.974, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[1] intercept   : AIC=77.908, Time=0.46 sec
#  ARIMA(2,1,3)(0,0,0)[1] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(3,1,0)(0,0,0)[1] intercept   : AIC=75.879, Time=0.25 sec
#  ARIMA(3,1,1)(0,0,0)[1] intercept   : AIC=77.682, Time=0.45 sec
#  ARIMA(3,1,2)(0,0,0)[1] intercept   : AIC=77.727, Time=0.56 sec
#  ARIMA(4,1,0)(0,0,0)[1] intercept   : AIC=77.556, Time=0.12 sec
#  ARIMA(4,1,1)(0,0,0)[1] intercept   : AIC=79.447, Time=0.63 sec
#  ARIMA(5,1,0)(0,0,0)[1] intercept   : AIC=79.543, Time=0.15 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[1] intercept
# Total fit time: 6.396 seconds
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(0, 0, 0, 1),
#       suppress_warnings=True)

# %%
# ARIMA 모델 
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# (AR=2, 차분=1, MA=2) 파라미터로 ARIMA 모델을 학습합니다.
model = ARIMA(sub_df_log.visit_pop_cnt.values, order=(0,1,1))     ##### 여기 order=(1,1,1)에 위에서 나온 숫자 넣는거 #####
                                   ##### 그리고 sub_df_log.waste_cnt.values에서 가운데 waste_cnt 각자걸로 바꾸기 #####

#trend : constant를 가지고 있는지, c - constant / nc - no constant
#disp : 수렴 정보를 나타냄
model_fit = model.fit(trend='c', full_output=True, disp=True)
print(model_fit.summary())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                   41
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                 -33.091
# Method:                       css-mle   S.D. of innovations              0.542
# Date:                Fri, 10 Sep 2021   AIC                             72.181
# Time:                        17:29:49   BIC                             77.322
# Sample:                             1   HQIC                            74.053
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1032      0.106     -0.973      0.330      -0.311       0.105
# ma.L1.D.y      0.2585      0.163      1.591      0.112      -0.060       0.577
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -3.8678           +0.0000j            3.8678            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# # 예측하기

# %%
# 2단위 이후의 예측결과
fore = model_fit.forecast(steps=2)
print(fore)

##### 맨 앞에 나온 'array([10681271.81014634, 10741037.02029268])' 이게 차례대로 7, 8월 예측값에 로그씌운거임 #####
##### 7월 : 10.05681231, 8월 : 10.28080669 #####
##### 이거 지수함수에 넣어서 원래값으로 돌려야 함 -> 각각 가져다 밑에 넣기 #####
# Out:
# (array([7.40105819, 7.29790372]), array([0.54188786, 0.87106315]), array([[6.3389775 , 8.46313887],
#        [5.59065133, 9.00515612]]))

# %%
# 이거 위에서 로그씌울 때 np.log1p 이거 써서 지수함수에 넣은 다음에 1 뺀거임
# https://rfriend.tistory.com/295
# 궁금하면 이 링크 들어가서 읽어보세요 질문받기 싫어서 미리 써놓음
# 밑에 어떻게 되는지 예제코드도 넣었으니까 제발 질문 안해주길 ㅎ

print( np.exp(7.40105819) - 1 )   ##### 괄호 안에 7월 숫자 넣기 #####
print( np.exp(7.29790372) - 1 )   ##### 괄호 안에 8월 숫자 넣기 #####

##### 이 값 가져다 엑셀파일에 입력하기 #####
# Out:
# 1636.7165286430084
# 1476.2000546882964
